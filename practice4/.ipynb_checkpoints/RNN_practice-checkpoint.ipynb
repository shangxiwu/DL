# %%
# -*- coding: utf-8 -*-
import os
import re
import numpy as np
import tensorflow as tf

tf.reset_default_graph()

train_pos = "movie_review/train/pos/"
train_neg = "movie_review/train/neg/"
test_pos = "movie_review/test/pos/"
test_neg = "movie_review/test/neg/"

epochs = 17
batch_size = 64
max_sequence_length = 150
rnn_size = 10
embedding_size = 50
min_word_frequency = 10
learning_rate = 0.0005

# %%
# -*- coding: utf-8 -*-
import os
import re
import numpy as np
import tensorflow as tf

tf.reset_default_graph()

train_pos = "movie_review/train/pos/"
train_neg = "movie_review/train/neg/"
test_pos = "movie_review/test/pos/"
test_neg = "movie_review/test/neg/"

epochs = 17
batch_size = 64
max_sequence_length = 150
rnn_size = 10
embedding_size = 50
min_word_frequency = 10
learning_rate = 0.0005
# Out:
# /home/isaac/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From <ipython-input-1-e8c56cafbf0d>:63: VocabularyProcessor.__init__ (from tensorflow.contrib.learn.python.learn.preprocessing.text) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.
# WARNING:tensorflow:From /home/isaac/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/preprocessing/text.py:154: CategoricalVocabulary.__init__ (from tensorflow.contrib.learn.python.learn.preprocessing.categorical_vocabulary) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.
# WARNING:tensorflow:From /home/isaac/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/preprocessing/text.py:170: tokenizer (from tensorflow.contrib.learn.python.learn.preprocessing.text) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.
# Vocabulary Size: 28685
# WARNING:tensorflow:From <ipython-input-1-e8c56cafbf0d>:92: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').
# Train Loss: 0.69, Train Acc: 0.45
# Train Loss: 0.69, Train Acc: 0.52
# Train Loss: 0.69, Train Acc: 0.39
# Train Loss: 0.69, Train Acc: 0.56
# Train Loss: 0.69, Train Acc: 0.48
# Train Loss: 0.69, Train Acc: 0.55
# Train Loss: 0.69, Train Acc: 0.47
# Train Loss: 0.69, Train Acc: 0.58
# Epoch: 1, Test Loss: 0.69, Test Acc: 0.52
# Train Loss: 0.69, Train Acc: 0.48
# Train Loss: 0.69, Train Acc: 0.45
# Train Loss: 0.69, Train Acc: 0.55
# Train Loss: 0.69, Train Acc: 0.5
# Train Loss: 0.69, Train Acc: 0.53
# Train Loss: 0.68, Train Acc: 0.56
# Train Loss: 0.65, Train Acc: 0.67
# Train Loss: 0.63, Train Acc: 0.72
# Epoch: 2, Test Loss: 0.66, Test Acc: 0.62
# Train Loss: 0.64, Train Acc: 0.67
# Train Loss: 0.66, Train Acc: 0.61
# Train Loss: 0.68, Train Acc: 0.55
# Train Loss: 0.61, Train Acc: 0.73
# Train Loss: 0.64, Train Acc: 0.67
# Train Loss: 0.65, Train Acc: 0.64
# Train Loss: 0.62, Train Acc: 0.64
# Train Loss: 0.52, Train Acc: 0.8
# Epoch: 3, Test Loss: 0.63, Test Acc: 0.67
# Train Loss: 0.61, Train Acc: 0.67
# Train Loss: 0.65, Train Acc: 0.61
# Train Loss: 0.64, Train Acc: 0.67
# Train Loss: 0.58, Train Acc: 0.72
# Train Loss: 0.6, Train Acc: 0.72
# Train Loss: 0.54, Train Acc: 0.75
# Train Loss: 0.66, Train Acc: 0.61
# Train Loss: 0.58, Train Acc: 0.7
# Epoch: 4, Test Loss: 0.59, Test Acc: 0.71
# Train Loss: 0.54, Train Acc: 0.75
# Train Loss: 0.53, Train Acc: 0.78
# Train Loss: 0.22, Train Acc: 0.92
# Train Loss: 0.37, Train Acc: 0.86
# Train Loss: 0.32, Train Acc: 0.86
# Epoch: 11, Test Loss: 0.43, Test Acc: 0.8
# Train Loss: 0.38, Train Acc: 0.83
# Train Loss: 0.24, Train Acc: 0.92
# Train Loss: 0.15, Train Acc: 0.95
# Train Loss: 0.53, Train Acc: 0.83
# Train Loss: 0.38, Train Acc: 0.86
# Train Loss: 0.41, Train Acc: 0.83
# Train Loss: 0.33, Train Acc: 0.89
# Train Loss: 0.27, Train Acc: 0.86
# Epoch: 12, Test Loss: 0.43, Test Acc: 0.81
# Train Loss: 0.43, Train Acc: 0.78
# Train Loss: 0.28, Train Acc: 0.91
# Train Loss: 0.24, Train Acc: 0.89
# Train Loss: 0.28, Train Acc: 0.92
# Train Loss: 0.33, Train Acc: 0.86
# Train Loss: 0.3, Train Acc: 0.89
# Train Loss: 0.4, Train Acc: 0.86
# Train Loss: 0.18, Train Acc: 0.89
# Epoch: 13, Test Loss: 0.41, Test Acc: 0.83
# Train Loss: 0.2, Train Acc: 0.95
# Train Loss: 0.24, Train Acc: 0.94
# Train Loss: 0.34, Train Acc: 0.84
# Train Loss: 0.23, Train Acc: 0.92
# Train Loss: 0.16, Train Acc: 0.94
# Train Loss: 0.13, Train Acc: 0.98
# Train Loss: 0.32, Train Acc: 0.89
# Train Loss: 0.26, Train Acc: 0.91
# Epoch: 14, Test Loss: 0.4, Test Acc: 0.82
# Train Loss: 0.26, Train Acc: 0.91
# Train Loss: 0.2, Train Acc: 0.94
# Train Loss: 0.12, Train Acc: 0.98
# Train Loss: 0.38, Train Acc: 0.84
# Train Loss: 0.27, Train Acc: 0.91
# Train Loss: 0.22, Train Acc: 0.94
# Train Loss: 0.25, Train Acc: 0.94
# Train Loss: 0.22, Train Acc: 0.92
# Epoch: 15, Test Loss: 0.4, Test Acc: 0.83
# Train Loss: 0.34, Train Acc: 0.89
# Train Loss: 0.24, Train Acc: 0.88
# Train Loss: 0.16, Train Acc: 0.95
# Train Loss: 0.2, Train Acc: 0.95
# Train Loss: 0.3, Train Acc: 0.88
# Train Loss: 0.26, Train Acc: 0.89
# Train Loss: 0.37, Train Acc: 0.8
# Train Loss: 0.27, Train Acc: 0.92
# Epoch: 16, Test Loss: 0.43, Test Acc: 0.83
# Train Loss: 0.27, Train Acc: 0.94
# Train Loss: 0.22, Train Acc: 0.94
# Train Loss: 0.32, Train Acc: 0.86
# Train Loss: 0.092, Train Acc: 0.98
# Train Loss: 0.27, Train Acc: 0.94
# Train Loss: 0.18, Train Acc: 0.94
# Train Loss: 0.12, Train Acc: 0.97
# Train Loss: 0.28, Train Acc: 0.91
# Epoch: 17, Test Loss: 0.4, Test Acc: 0.83
