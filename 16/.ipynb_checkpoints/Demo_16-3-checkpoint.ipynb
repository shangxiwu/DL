# %% [markdown]
# # 產生word2vec訓練資料

# %%
from __future__ import print_function
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)

def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))

vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)   # data 為字id, count 為字出現次數, dictionary 為id 對應的
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'originated', 'as', 'of', 'term']

# %% [markdown]
# # Word2vec模型建立

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From C:\Users\Student\.conda\envs\Deep Learning\lib\site-packages\tensorflow_core\python\training\adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From <ipython-input-3-6cf1e824a44a>:48: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
              # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.249944
# Nearest to he: desylva, fuelling, poisson, reminder, happen, removed, conceive, osama,
# Nearest to not: interspersed, fetuses, gretzky, edmonton, resettlement, dumping, rogue, masculinity,
# Nearest to who: demonstrations, mung, restricting, standing, elaborately, praetorian, priest, heme,
# Nearest to more: precipitate, bartlett, lug, fusing, trypanosomiasis, peculiarity, balloons, allows,
# Nearest to or: condone, balloons, klan, surfer, reigning, intracranial, accomplices, fide,
# Nearest to some: capping, footwork, bb, strangled, funniest, pox, charges, soga,
# Nearest to his: symonds, grease, lethality, iambic, genuineness, overtaking, plasma, unbearable,
# Nearest to if: petrochemical, brel, domitian, violates, polydor, alia, duplex, yaoi,
# Nearest to than: provision, democrat, conserve, chevron, unofficial, northumberland, fulltext, cantos,
# Nearest to s: defines, symmetries, semimajor, ribeira, knobs, push, docked, radicals,
# Nearest to at: rhein, unwelcome, griswold, dyskinesia, disrespectful, unaffected, zut, sundial,
# Nearest to about: octavio, kirk, mcg, dipped, werewolf, ethnographic, constructivists, eiga,
# Nearest to history: eating, contacts, troublesome, krishna, scrap, uneasy, surreptitiously, link,
# Nearest to but: parkes, supermassive, northeastern, physiologist, happy, twigs, excelling, poorest,
# Nearest to UNK: medici, trooper, ztas, ige, dobb, vinny, protecting, minorities,
# Nearest to most: dessert, diels, mendoza, nguyen, convertible, timing, erosive, preserving,
# Average loss at step 2000: 4.370959
# Average loss at step 4000: 3.863969
# Average loss at step 6000: 3.791596
# Average loss at step 8000: 3.690401
# Average loss at step 10000: 3.616499
# Nearest to he: it, they, she, who, kaunas, there, min, daimyo,
# Nearest to not: masculinity, to, it, fetuses, fibers, be, previously, they,
# Nearest to who: and, macpherson, he, which, dog, they, demonstrations, decentralisation,
# Nearest to more: lug, trypanosomiasis, peculiarity, memorably, fusing, bartlett, precipitate, pinstripes,
# Nearest to or: and, racial, fide, without, discos, ecc, rajonas, phases,
# Nearest to some: many, these, other, several, wuthering, filk, remote, bb,
# Nearest to his: their, the, her, s, its, entrepot, sentience, statewide,
# Nearest to if: brel, yaoi, pathetic, phoned, veal, satisfies, when, domitian,
# Nearest to than: provision, widescreen, democrat, unofficial, duodenum, fulltext, echols, sounding,
# Nearest to s: leech, his, pluralized, and, hurry, elias, cdf, was,
# Nearest to at: after, in, with, by, during, on, casualty, like,
# Nearest to about: mcg, liliuokalani, omari, superpowers, gardiner, loudly, werewolf, desktop,
# Nearest to history: troublesome, transferable, various, lillard, eating, video, eurozone, scrap,
# Nearest to but: and, although, still, schultz, unanswered, czes, adv, saxons,
# Nearest to UNK: ige, console, kaunas, archiepiscopal, stomachs, putonghua, crossbar, robber,
# Nearest to most: mendoza, attorneys, ism, preserving, gting, nguyen, majors, convertible,
# Average loss at step 12000: 3.602234
# Average loss at step 14000: 3.572918
# Average loss at step 16000: 3.409572
# Average loss at step 18000: 3.455362
# Average loss at step 20000: 3.543835
# Nearest to he: it, she, they, who, there, which, musik, actually,
# Nearest to not: usually, it, rogue, they, still, to, who, ldp,
# Nearest to who: he, which, often, they, macpherson, lor, there, nativity,
# Nearest to more: less, most, lug, very, precipitate, presenter, peculiarity, trypanosomiasis,
# Nearest to or: and, than, slavonic, discos, racial, climatic, without, alessandro,
# Nearest to some: many, these, several, other, all, their, his, wuthering,
# Nearest to his: their, her, its, the, some, entrepot, highland, grease,
# Nearest to if: when, so, but, phoned, yaoi, geer, satisfies, hideous,
# Nearest to than: or, provision, echols, unofficial, ymca, restarted, fulltext, sounding,
# Nearest to s: hula, flotilla, clergymen, manson, materialised, affectation, leech, decompose,
# Nearest to at: in, after, with, on, during, rationalisation, and, of,
# Nearest to about: mcg, superpowers, nine, kirk, eiga, strata, electrochemistry, dipped,
# Nearest to history: troublesome, wells, billboard, host, transferable, moldova, crosby, various,
# Nearest to but: although, however, which, and, if, that, though, does,
# Nearest to UNK: ler, capita, agave, ivorian, widows, interrupt, dresses, rida,
# Nearest to most: ism, more, many, preserving, mendoza, same, convertible, bodhisattvas,
# Average loss at step 22000: 3.498589
# Average loss at step 24000: 3.488091
# Average loss at step 26000: 3.484298
# Average loss at step 28000: 3.481000
# Average loss at step 30000: 3.503922
# Nearest to he: she, it, they, who, there, kaunas, daimyo, deacons,
# Nearest to not: they, still, usually, there, it, officially, therefore, paused,
# Nearest to who: he, they, which, she, macpherson, often, hieroglyph, there,
# Nearest to more: less, most, very, lug, trypanosomiasis, rather, presenter, holding,
# Nearest to or: and, slavonic, than, but, without, as, racial, tiglath,
# Nearest to some: many, these, several, their, all, most, other, any,
# Nearest to his: her, their, its, the, our, s, your, entrepot,
# Nearest to if: when, phoned, before, so, but, because, where, though,
# Nearest to than: or, provision, yorkers, echols, ymca, fulltext, justifications, much,
# Nearest to s: her, his, hci, cbd, and, alessandro, dunkeld, crs,
# Nearest to at: in, during, after, on, ruined, ddr, moro, visualisation,
# Nearest to about: kirk, strata, yod, wpm, vasily, eiga, reassert, on,
# Nearest to history: host, asis, billboard, troublesome, moldova, wells, transferable, unconstitutional,
# Nearest to but: although, however, which, and, that, while, if, salicylate,
# Nearest to UNK: antisense, cured, hippo, ler, com, vinny, stylist, butchers,
# Nearest to most: more, some, many, ism, convertible, infoplease, mendoza, preserving,
# Average loss at step 32000: 3.501002
# Average loss at step 34000: 3.498983
# Average loss at step 36000: 3.456116
# Average loss at step 38000: 3.298483
# Average loss at step 40000: 3.432180
# Nearest to he: she, it, they, who, there, later, paine, i,
# Nearest to not: usually, still, it, they, never, prevails, therefore, contemplate,
# Nearest to who: which, he, often, they, disguise, that, macpherson, also,
# Nearest to more: less, most, very, greater, rather, sponsor, lug, precipitate,
# Nearest to or: and, than, slavonic, cumann, without, storms, fibrosis, clocked,
# Nearest to some: many, these, several, both, their, any, most, such,
# Nearest to his: her, their, your, its, my, our, the, s,
# Nearest to if: when, where, though, then, because, before, phoned, hideous,
# Nearest to than: or, yorkers, objectionable, provision, much, echols, shine, allafrica,
# Nearest to s: leech, his, her, sardar, cbd, dunkeld, wounds, supervisors,
# Nearest to at: in, during, on, moro, tsarina, nic, ruined, bullet,
# Nearest to about: wpm, longship, reassert, between, strata, adapa, josh, engraving,
# Nearest to history: host, unconstitutional, billboard, troublesome, wells, crosby, principals, physik,
# Nearest to but: however, although, and, while, though, before, harmonize, it,
# Nearest to UNK: b, techstep, castrated, ide, carleton, mabuse, gumby, stalls,
# Nearest to most: more, many, among, some, ism, zechs, hakim, earliest,
# Average loss at step 42000: 3.435220
# Average loss at step 44000: 3.451348
# Average loss at step 46000: 3.447906
# Average loss at step 48000: 3.355831
# Average loss at step 50000: 3.383022
# Nearest to he: she, it, they, who, there, this, then, paine,
# Nearest to not: usually, still, it, generally, now, officially, they, regimes,
# Nearest to who: which, he, they, macpherson, lor, named, she, often,
# Nearest to more: less, most, very, rather, pilots, too, stronger, lug,
# Nearest to or: and, than, slavonic, clocked, fibrosis, cumann, labeled, prefaced,
# Nearest to some: many, these, several, both, most, numerous, the, various,
# Nearest to his: her, their, its, my, your, the, our, whose,
# Nearest to if: when, where, though, although, before, because, while, but,
# Nearest to than: or, yorkers, objectionable, sounding, much, echols, provision, and,
# Nearest to s: her, hurry, his, whose, leech, marshallese, supervisors, cbd,
# Nearest to at: during, on, in, washtenaw, kickstart, scala, rcaf, ulvaeus,
# Nearest to about: between, engraving, longship, elbing, pin, wpm, intermittently, fairey,
# Nearest to history: host, unconstitutional, principals, wells, asis, har, cke, list,
# Nearest to but: however, although, while, and, though, when, if, during,
# Nearest to UNK: et, http, von, widows, enzyte, j, jolson, hein,
# Nearest to most: more, many, some, among, less, preserving, zechs, infoplease,
# Average loss at step 52000: 3.436572
# Average loss at step 54000: 3.431450
# Average loss at step 56000: 3.440554
# Average loss at step 58000: 3.399848
# Average loss at step 60000: 3.394589
# Nearest to he: she, it, they, who, there, later, we, never,
# Nearest to not: usually, still, now, they, always, it, generally, almost,
# Nearest to who: he, which, they, she, often, lor, named, hieroglyph,
# Nearest to more: less, most, very, rather, too, greater, larger, stronger,
# Nearest to or: and, than, slavonic, lightsabers, but, fibrosis, applicable, like,
# Nearest to some: many, these, several, both, most, any, all, the,
# Nearest to his: her, their, its, my, your, our, entrepot, whose,
# Nearest to if: when, where, though, because, before, then, although, however,
# Nearest to than: or, yorkers, but, provision, objectionable, and, rumoured, much,
# Nearest to s: whose, hci, deformation, although, hurry, wounds, turku, semiotics,
# Nearest to at: during, scala, in, within, griswold, hypertrophy, ddr, kickstart,
# Nearest to about: engraving, conformance, between, longship, happily, bad, totaling, heavier,
# Nearest to history: list, host, mvd, virgil, montserrat, har, propulsion, millionth,
# Nearest to but: however, although, and, while, though, when, is, or,
# Nearest to UNK: ero, purebred, perpetually, widows, remote, impoverished, et, hamm,
# Nearest to most: more, many, some, among, use, earliest, ism, hakim,
# Average loss at step 62000: 3.244263
# Average loss at step 64000: 3.254155
# Average loss at step 66000: 3.406542
# Average loss at step 68000: 3.396056
# Average loss at step 70000: 3.360371
# Nearest to he: she, it, they, there, who, we, later, never,
# Nearest to not: still, usually, now, generally, almost, always, never, also,
# Nearest to who: which, he, they, lor, she, nor, still, macpherson,
# Nearest to more: less, most, very, rather, too, larger, stronger, pilots,
# Nearest to or: and, than, fibrosis, any, like, discos, tychonoff, slavonic,
# Nearest to some: many, several, these, both, most, all, any, those,
# Nearest to his: her, their, its, my, your, our, entrepot, the,
# Nearest to if: when, though, where, because, before, phoned, however, thus,
# Nearest to than: or, provision, rumoured, yorkers, echols, and, encha, but,
# Nearest to s: whose, the, dunkeld, byte, crs, gottwald, flotilla, single,
# Nearest to at: during, on, caribou, within, in, ruined, ddr, under,
# Nearest to about: totaling, engraving, cle, on, over, elbing, bad, logarithms,
# Nearest to history: list, mvd, host, har, generalized, survey, virgil, heritage,
# Nearest to but: however, although, and, that, which, while, though, still,
# Nearest to UNK: max, enzyte, horns, ulrich, stored, hippo, foil, grammatically,
# Nearest to most: more, many, some, less, use, among, all, hakim,
# Average loss at step 72000: 3.375465
# Average loss at step 74000: 3.346201
# Average loss at step 76000: 3.315675
# Average loss at step 78000: 3.350976
# Average loss at step 80000: 3.375611
# Nearest to he: she, it, they, who, there, paine, later, initially,
# Nearest to not: still, usually, always, often, actually, generally, almost, it,
# Nearest to who: he, which, she, they, often, never, lor, still,
# Nearest to more: less, very, most, rather, too, stronger, quite, smaller,
# Nearest to or: and, than, foobar, but, while, like, fibrosis, discos,
# Nearest to some: many, several, these, most, both, various, all, numerous,
# Nearest to his: her, their, my, its, your, our, entrepot, tarr,
# Nearest to if: when, though, where, before, because, then, although, so,
# Nearest to than: or, but, much, while, rumoured, provision, and, encha,
# Nearest to s: marshallese, bosman, dunkeld, leech, lit, pisan, affectation, pinochet,
# Nearest to at: during, in, caribou, on, kickstart, within, near, ddr,
# Nearest to about: over, logarithms, cle, engraving, intermittently, totaling, erlbaum, affirmative,
# Nearest to history: list, mvd, survey, har, pumping, host, geography, virgil,
# Nearest to but: however, although, and, while, though, than, which, or,
# Nearest to UNK: ler, berth, manar, detrimental, jean, bottlenose, brien, ige,
# Nearest to most: more, some, many, less, among, earliest, hakim, myth,

# %% [markdown]
# # 可視化word2vec結果

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                        ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
